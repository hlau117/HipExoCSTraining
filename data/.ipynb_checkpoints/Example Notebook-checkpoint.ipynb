# %%
import numpy as np
import pickle
from matplotlib import pyplot as plt

# %%
data_file = np.loadtxt('labeled_CW_ZI_1')
print(data_file.shape)
# Out:
# (4985, 15)

# %%
# Out:
# (4855, 15)

# %%
plt.plot(data_file[:,1])
